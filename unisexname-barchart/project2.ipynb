# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('unisexname.csv')
data = data.head(10)

# %%
names = data[['name']]

# %%
totals = data[['total']]

# %%
data.plot.bar('name','total')
plt.title('Top Ten Unisex Name and Living People with The Name')
plt.ylabel('Total')
plt.xlabel('Names')
# Out:
# Text(0.5, 0, 'Names')
